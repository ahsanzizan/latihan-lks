# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv('./datasets/train.csv')
print(train.head())
print("Length: ", len(train))
# Out:
#   UniqueId  SocialMedia  SocialMediaTime  News  NewsTime  Blogs  BlogsTime  \
# 0   000x41          3.0           87.833   0.0       0.0   27.0    798.333
# 1   000x4c         10.0         1005.667   0.0       0.0   36.0   2111.342
# 2   000x65          4.0           61.000   0.0       0.0   19.0    607.000
# 3   000xc6          0.0            0.000   0.0       0.0   17.0    840.233
# 4   000xc7          3.0           94.000   2.0     125.0   55.0   1970.845
#
#    BounceRate  ExitRate  PageValue TrafficKind       OS        Browser Month  \
# 0       0.000     0.013     22.916      search  windows  Google-Chrome   Feb
# 1       0.004     0.014     11.439      direct  windows          Other   Feb
# 2       0.000     0.027     17.536    referral  android         Safari   Feb
# 3       0.000     0.002    109.176      direct  windows  Google-Chrome   Mar
# 4       0.000     0.002     96.255      direct  windows        Firefox   Mar
#
#                Region VisitorKind  DayImportance  IsWeekend  IsSale
# 0  East North Central   Returning            0.8        0.0    True
# 1         New England   Returning            0.0        0.0    True
# 2  West South Central   Returning            1.0        1.0    True
# 3             Pacific         New            0.0        0.0    True
# 4         New England         New            0.0        1.0    True
# Length:  2908

# %%
train = train.dropna()
len(train)
# Out:
# 2821

# %%
train.isna().sum()
# Out:
# UniqueId           0
# SocialMedia        0
# SocialMediaTime    0
# News               0
# NewsTime           0
# Blogs              0
# BlogsTime          0
# BounceRate         0
# ExitRate           0
# PageValue          0
# TrafficKind        0
# OS                 0
# Browser            0
# Month              0
# Region             0
# VisitorKind        0
# DayImportance      0
# IsWeekend          0
# IsSale             0
# dtype: int64

# %%
train = train.drop(['UniqueId'], axis=1)

# %%
train.describe()
# Out:
#        SocialMedia  SocialMediaTime         News     NewsTime        Blogs  \
# count  2821.000000      2821.000000  2821.000000  2821.000000  2821.000000
# mean      2.716767        94.886645     0.605814    42.624563    37.519674
# std       3.537975       185.961218     1.329649   144.879136    50.000845
# min     -10.000000         0.000000     0.000000     0.000000     0.000000
# 25%       0.000000         0.000000     0.000000     0.000000    10.000000
# 50%       1.000000        26.500000     0.000000     0.000000    22.000000
# 75%       4.000000       116.000000     1.000000     0.000000    44.000000
# max      27.000000      2720.500000    12.000000  1767.667000   584.000000
#
#           BlogsTime   BounceRate     ExitRate    PageValue  DayImportance  \
# count   2821.000000  2821.000000  2821.000000  2821.000000    2821.000000
# mean    1434.944442     0.015788     0.034371    14.179981       0.044452
# std     2018.829784     0.039431     0.041039    27.910909       0.172575
# min        0.000000     0.000000     0.000000     0.000000       0.000000
# 25%      285.500000     0.000000     0.012000     0.000000       0.000000
# 50%      794.713000     0.001000     0.021000     0.000000       0.000000
# 75%     1758.250000     0.012000     0.038000    17.930000       0.000000
# max    27009.859000     0.200000     0.200000   360.953000       1.000000
#
#          IsWeekend
# count  2821.000000
# mean      0.260900
# std       0.439204
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
class LogisticRegression:
    def __init__(self, learning_rate=0.001, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.weights = None
        self.bias = None
        self.losses = []
         
    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def compute_loss(self, y_true: np.ndarray, y_pred: np.ndarray):
        epsilon = 1e-9
        y1 = y_true * np.log(y_pred + epsilon)
        y2 = (1-y_true) * np.log(1 - y_pred + epsilon)
        return -np.mean(y1 + y2)

    def feed_forward(self,X):
        z = np.dot(X, self.weights) + self.bias
        A = self._sigmoid(z)
        return A

    def fit(self, X: np.ndarray, y: np.ndarray):
        n_samples, n_features = X.shape

        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iters):
            A = self.feed_forward(X)
            self.losses.append(self.compute_loss(y,A))
            dz = A - y 
            
            dw = (1 / n_samples) * np.dot(X.T, dz)
            db = (1 / n_samples) * np.sum(dz)
            
            self.weights -= self.lr * dw
            self.bias -= self.lr * db
            
    def predict(self, X: np.ndarray):
        threshold = .5
        y_hat = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(y_hat)
        y_predicted_cls = [1 if i > threshold else 0 for i in y_predicted]
        
        return np.array(y_predicted_cls)

# %%
def standard_scaler(X: np.ndarray):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    
    return (X - mean) / std

# %%
X1_train = np.asarray(train['BlogsTime'].values.tolist())
X2_train = np.asarray(train['PageValue'].values.tolist())

X_train = np.column_stack((X1_train, X2_train))
X_train_scaled = standard_scaler(X_train)

y_train = np.asarray(train['IsSale'].values.tolist())

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# %%
test = pd.read_csv('./datasets/test.csv')
test.isna().sum()
# Out:
# UniqueId            0
# SocialMedia         2
# SocialMediaTime     6
# News                8
# NewsTime            2
# Blogs               4
# BlogsTime           3
# BounceRate         11
# ExitRate            7
# PageValue           3
# TrafficKind         6
# OS                  6
# Browser             4
# Month               5
# Region              6
# VisitorKind         4
# DayImportance       5
# IsWeekend           7
# dtype: int64

# %%
len(test)
# Out:
# 1000

# %%
test = test.dropna()
len(test)
# Out:
# 973

# %%
X1_test = np.asarray(test['BlogsTime'].values.tolist())
X2_test = np.asarray(test['PageValue'].values.tolist())

X_test = np.column_stack((X1_test, X2_test))
X_test_scaled = standard_scaler(X_test)

# %%
predictions = model.predict(X_test_scaled)

# %%
# Write the submission to submission.csv
submission = test
submission['isSale'] = ["true" if i == 1 else "false" for i in predictions]
submission.to_csv("submission.csv")
print("Successfully written the predictions to submission.csv")
# Out:
#     UniqueId  SocialMedia  SocialMediaTime  News  NewsTime  Blogs  BlogsTime  \
# 0     0x1de1          5.0          277.800   0.0       0.0   25.0    884.500
# 1     0x21eb          7.0          190.438   0.0       0.0   60.0   1967.780
# 2     0x2f6a          0.0            0.000   0.0       0.0    5.0    586.000
# 3     0x25f0          2.0           88.000  10.0     719.0   54.0   1986.553
# 4     0x2be0         12.0         1276.264   0.0       0.0  118.0   3215.173
# ..       ...          ...              ...   ...       ...    ...        ...
# 995   0x123c          1.0           54.000   0.0       0.0   31.0   2543.500
# 996   00x5e8          6.0          408.200   0.0       0.0   33.0    878.624
# 997   0x19b7          6.0          189.800   0.0       0.0    9.0    208.833
# 998   0x17b2         14.0         1220.914   4.0    1005.4  280.0  18171.795
# 999   00x306          0.0            0.000   0.0       0.0    1.0      0.000
#
#      BounceRate  ExitRate  PageValue TrafficKind       OS        Browser  \
# 0         0.000     0.004      7.481      direct  windows          Other
# 1         0.004     0.015      2.627    referral  mac-ios  Google-Chrome
# 2         0.000     0.060      0.000    referral  windows        Firefox
# 3         0.005     0.020     25.827      direct  android         Safari
# 4         0.000     0.005     22.458      search  mac-ios  Google-Chrome
# ..          ...       ...        ...         ...      ...            ...
# 995       0.000     0.007      0.000      direct  windows  Google-Chrome
# 996       0.000     0.020     19.365      direct  windows  Google-Chrome
# 997       0.000     0.015     70.316      direct  windows  Google-Chrome
# 998       0.017     0.039      5.698      search  windows  Google-Chrome
# 999       0.200     0.200      0.000      search  windows  Google-Chrome
#
#     Month              Region VisitorKind  DayImportance  IsWeekend isSale
# 0     Jul        Mid-Atlantic         New            0.0        1.0  false
# 1     Dec            Mountain   Returning            0.0        1.0  false
# 2     Nov             Pacific   Returning            0.0        1.0  false
# 3     Dec        Mid-Atlantic   Returning            0.0        0.0   true
# 4     Nov            Mountain   Returning            0.0        0.0   true
# ..    ...                 ...         ...            ...        ...    ...
# 995   May      South Atlantic   Returning            0.0        0.0  false
# 996   Mar         New England   Returning            0.0        0.0  false
# 997   Nov  East North Central         New            0.0        0.0   true
# 998   Jul         New England   Returning            0.0        0.0   true
# 999   Mar  West North Central   Returning            0.0        0.0  false
#
# [973 rows x 19 columns]
